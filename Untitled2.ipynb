# %%
#Defining the variables:
#1. Places == rooms
#2. Passages == dors
#3. Characters
#4. ¿Objects? == keys

king_neptune = {
    "name": "King Neptune",
    "type": "passage",
}

#stedywinds = {
#    "name": "Stedy Winds",
#    "type": "passage",}

sacrifice_rum = {
    "name": "Rum",
    "type": "key",
    "target": "Safe passage",
}
sacrifice_goat = {
    "name": "Goat",
    "type": "key",
    "target": "Safe passage",
}
sacrifice_ring = {
    "name": "Wedding Ring",
    "type": "key",
    "target": "Game Over",
}
sacrifice_rosary = {
    "name": "Rosary",
    "type": "key",
    "target": "Game Over",
}
mast = {
    "name": "Main mast",
    "type": "furniture",
}
storm = {
    "name": "Storm",
    "type": "room",
}

safe_sail = {
    "name": "Safe sail",
    "type": "room",
}

destination = {
    "name": "Brasil"
}

storm_rooms = [storm, safe_sail, destination]
storm_doors = [king_neptune]

# define which items/rooms are related
object_relations = {
    "Storm": [king_neptune, mast],
    "sacrifice": [sacrifice_rum, sacrifice_goat, sacrifice_ring, sacrifice_rosary],
    "Storm": [storm, destination],
    "Brasil": [stedywinds]
}
STORM_GAME_STATE = {
    "current_room": storm,
    "keys_collected": [],
    "target_room": destination
}

from sys import exit
import time

def linebreak():
    """
    Print a line break
    """
    print("\n\n")
def game_storm():
    """
    Start the storm
    """
    print("A storm came from nowere, the crew runs to their designed roles, the timonner strugles to keep a safe route. Suddlenty a rope whips a crack on the air, the main sail just falls while it was retracted, the crew hope and morale just cracks as they whacth powerless their doom. Everyone konws the main mast will not resist to that wind... You hear someone screaming breking through the roaming storm, and more screams while a giant wave form at the starbord of the ship. You try your best to ignore, imaging your mates being throwed by the gusty winds just to been swallowed by the raging waves... When a mate pull your sholder: Neptune! King Neptune is here!")
    print("King Neptune: I demmand a sacrifice! If acceptble then I shall grant you stedy winds and a safe sail.")
    storm_room(game_state["storm"])
def storm_room(room):
    """
    Play a room. First check if the sacrifice is accepted.
    If it is, the storm will end with success. Otherwise, one of the conditions will return a gameover.
    """
    game_storm["Storm"] = storm
    if(game_state["Storm"] == game_state["Safe Sail"]):
        print("You made it! The storm start to fade as the sunset gently revels a clear sky and the cartografer are able to point where the ship are.")
def storm(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["Storm"] for i in object_relations[room["Storm"]]]
    print("You run all the ship for items to sacrifice. There is " + room["Storm"] + ". You find " + ", ".join(items))
def safe_sail(passage, storm):
    """
    From object_relations, find the two rooms connected to the given passage.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[passage["Stedy winds"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room
def examine_item(item_name):
    """
    Examine an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    storm_room = game_state["Storm"]
    safe_sail = ["Safe Sail"]
    output = None
    for item in object_relations[storm_room["Storm"]]:
        if(item["name"] == item_name):
            output = "You offered: " + item_name + "."
                for key in input["rum", "goat"]:
                    if(key["target"] == item):
                        accepted = True
                for key in input["Ring", "Wedding ring", "wedding ring", "ring"]:
                    print("Neptune: If you are giving up your commitement with who you love there is no one to come back to, so you will not be back.")
                        accepted = False
                for key in input["Rosary", "rosary"]:
                    print("Neptune: If you are giving up your faith there is no reason to continue your jorney in life, so I will claim it.")
                        accepted = False
                if(accepted = True):
                    output += "Your sacrifice was accepted."
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "Your sacifice was not accepted."
                    time.clock(5)
                    print("Game Over ")
        intended_action = input("What would you like to 'restart'? Type: y or n").strip()
        if intended_action == "y":
            #Reboot??
            return start_game
        else:
            print("Thank you for playing.")
            print("       The end        ")
            time.clock(5)
            exit()
    if(output is None):
        print("You must sacrifice something.")
    if(safe_sail and output("You made it!")):
# Out:
#   File "/var/folders/zl/64_yxwls4ld4zjxrnk6t2yth0000gn/T/ipykernel_97411/1079750670.py", line 125
#     for key in input["rum", "goat"]:
#     ^
# IndentationError: unexpected indent
